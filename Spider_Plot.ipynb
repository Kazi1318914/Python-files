# %% [markdown]
# # Mult TCGA

# %%
# Libraries
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# Set data
df = pd.DataFrame({
'Gene': ['105','204','571','743','899'],
'KNN': [1,1, 1, 0.99,0.99],
'RF': [1, 1, 1, 1,0.99],
'L-SVM': [0.96, 0.95, 0.97, 0.97,0.98],
'R-SVM': [0.89, 0.87, 0.88, 0.88,0.90],
'ADB': [0.3, 0.3, 0.19, 0.19,0.2],
'NN': [0.98, 0.98, 0.98, 0.99,0.99]
})
 
# ------- PART 1: Define a function that do a plot for one line of the dataset!
 
def make_spider( row, title, color):

    # number of variable
    categories=list(df)[1:]
    N = len(categories)

    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    ax = plt.subplot(1,5,row+1, polar=True, )

    # If you want the first axis to be on top:
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    
    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='grey', size=15)

    # Draw ylabels
    ax.set_rlabel_position(22)
    plt.yticks([0.10,0.30,0.60], ["0.10","0.30","0.60"], color="grey", size=7)
    plt.ylim(-0.1,1.1)

    # Ind1
    values=df.loc[row].drop('Gene').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, color=color, linewidth=2, linestyle='solid')
    for i,j in zip(angles, values):
      ax.annotate(str(j),xy=(i,j),ha='center')
    ax.fill(angles, values, color=color, alpha=0.4)

    # Add a title
    plt.title(title, size=11, color=color, y=1.1)

    
# ------- PART 2: Apply the function to all individuals
# initialize the figure
my_dpi=96
plt.figure(figsize=(2000/my_dpi, 2000/my_dpi), dpi=my_dpi)
 
# Create a color palette:
my_palette = plt.cm.get_cmap("Set2", len(df.index))
 
# Loop to plot
for row in range(0, len(df.index)):
    make_spider( row=row, title=df['Gene'][row]+' genes', color=my_palette(row))

# %% [markdown]
# # Multi Geo

# %%
# Libraries
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# Set data
df = pd.DataFrame({
'Gene': ['105','204','571','743','899'],
'KNN': [0.86, 0.83, 0.80, 0.77,0.79],
'RF': [1, 1, 1, 1,1],
'L-SVM': [0.0, 0.0, 0.0, -0.008,-0.0740],
'R-SVM': [0.87, 0.89, 0.86, 0.83,0.83],
'ADB': [0.98, 0.99, 0.998, 1,0.95],
'NN': [0.93, 0.93, 0.96, 0.95,0.93]
})
 
# ------- PART 1: Define a function that do a plot for one line of the dataset!
 
def make_spider( row, title, color):

    # number of variable
    categories=list(df)[1:]
    N = len(categories)

    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    ax = plt.subplot(1,5,row+1, polar=True, )

    # If you want the first axis to be on top:
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    
    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='grey', size=15)

    # Draw ylabels
    ax.set_rlabel_position(22)
    plt.yticks([0.10,0.30,0.60], ["0.10","0.30","0.60"], color="grey", size=7)
    plt.ylim(-0.1,1.1)

    # Ind1
    values=df.loc[row].drop('Gene').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, color=color, linewidth=2, linestyle='solid')
    for i,j in zip(angles, values):
      ax.annotate(str(j),xy=(i,j),ha='center')
    ax.fill(angles, values, color=color, alpha=0.4)

    # Add a title
    plt.title(title, size=11, color=color, y=1.1)

    
# ------- PART 2: Apply the function to all individuals
# initialize the figure
my_dpi=96
plt.figure(figsize=(2000/my_dpi, 2000/my_dpi), dpi=my_dpi)
 
# Create a color palette:
my_palette = plt.cm.get_cmap("Set2", len(df.index))
 
# Loop to plot
for row in range(0, len(df.index)):
    make_spider( row=row, title=df['Gene'][row]+' genes', color=my_palette(row))

# %% [markdown]
# # binary TCGA

# %%
# Libraries
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# # Set data
# df = pd.DataFrame({
# 'Gene': ['105','204','571','743','899'],
# 'KNN': [0.97, 0.97, 0.97, 0.96,0.98],
# 'RF': [0.97, 0.96, 0.96, 0.97, 0.96],
# 'L-SVM': [0.67, 0.72, 0.74, 0.78,0.79],
# 'R-SVM': [0.63, 0.66, 0.67, 0.67,0.69],
# 'ADB': [0.76, 0.82, 0.81, 0.81,0.82],
# 'NN': [0.84, 0.94, 0.92, 0.83,0.94]
# })


df = pd.DataFrame({
'Gene': ['105','204','571','743','899'],
'KNN': [1, 1, 1, 0.99,1],
'RF': [1, 1, 1, 0.99, 0.99],
'L-SVM': [0.93, 0.95, 0.95, 0.96,0.96],
'R-SVM': [0.93, 0.93, 0.93, 0.93,0.93],
'ADB': [0.96, 0.97, 0.97, 0.97,0.97],
'NN': [0.97, 0.99, 0.99, 0.98,0.99]
})
 
# ------- PART 1: Define a function that do a plot for one line of the dataset!
 
def make_spider( row, title, color):

    # number of variable
    categories=list(df)[1:]
    N = len(categories)

    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    ax = plt.subplot(1,5,row+1, polar=True, )

    # If you want the first axis to be on top:
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    
    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='grey', size=15)

    # Draw ylabels
    ax.set_rlabel_position(22)
    plt.yticks([0.10,0.30,0.60], ["0.10","0.30","0.60"], color="grey", size=7)
    plt.ylim(-0.1,1.1)

    # Ind1
    values=df.loc[row].drop('Gene').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, color=color, linewidth=2, linestyle='solid')
    for i,j in zip(angles, values):
      ax.annotate(str(j),xy=(i,j),ha='center')
    ax.fill(angles, values, color=color, alpha=0.4)

    # Add a title
    plt.title(title, size=11, color=color, y=1.1)

    
# ------- PART 2: Apply the function to all individuals
# initialize the figure
my_dpi=96
plt.figure(figsize=(2000/my_dpi, 2000/my_dpi), dpi=my_dpi)
 
# Create a color palette:
my_palette = plt.cm.get_cmap("Set2", len(df.index))
 
# Loop to plot
for row in range(0, len(df.index)):
    make_spider( row=row, title=df['Gene'][row]+' genes', color=my_palette(row))

# %% [markdown]
# # binary Geo

# %%
# Libraries
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# Set data
df = pd.DataFrame({
'Gene': ['105','204','571','743','899'],
'KNN': [0.98, 0.97, 0.94, 0.92,0.91],
'RF': [0.998, 1, 1, 1,1],
'L-SVM': [-0.0015,0.61,0.69,0.74,0.77],
'R-SVM': [0.96, 0.96, 0.99, 0.9,0.9],
'ADB': [1, 1, 1, 1,1],
'NN': [0.97, 0.98, 0.98, 0.98,0.97]
})
 
# ------- PART 1: Define a function that do a plot for one line of the dataset!
 
def make_spider( row, title, color):

    # number of variable
    categories=list(df)[1:]
    N = len(categories)

    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    ax = plt.subplot(1,5,row+1, polar=True, )

    # If you want the first axis to be on top:
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    
    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='grey', size=15)

    # Draw ylabels
    ax.set_rlabel_position(22)
    plt.yticks([0.10,0.30,0.60], ["0.10","0.30","0.60"], color="grey", size=7)
    plt.ylim(-0.1,1.1)

    # Ind1
    values=df.loc[row].drop('Gene').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, color=color, linewidth=2, linestyle='solid')
    for i,j in zip(angles, values):
      ax.annotate(str(j),xy=(i,j),ha='center')
    ax.fill(angles, values, color=color, alpha=0.4)

    # Add a title
    plt.title(title, size=11, color=color, y=1.1)

    
# ------- PART 2: Apply the function to all individuals
# initialize the figure
my_dpi=96
plt.figure(figsize=(2000/my_dpi, 2000/my_dpi), dpi=my_dpi)
 
# Create a color palette:
my_palette = plt.cm.get_cmap("Set2", len(df.index))
 
# Loop to plot
for row in range(0, len(df.index)):
    make_spider( row=row, title=df['Gene'][row]+' genes', color=my_palette(row))
