# %%
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold

# %%
pos_5289 = "/content/drive/My Drive/fasta dataset/A.thaliana5289_pos/kmer2/A.thaliana5289_pos_kmer_dnc_2.npy"
neg_5289 = "/content/drive/My Drive/fasta dataset/A.thaliana5289_neg/kmer2/A.thaliana5289_neg_kmer_dnc.npy"
pos_1000 = "/content/drive/My Drive/fasta dataset/A.thaliana1000indep_pos/kmer2/A.thaliana1000indep_pos_kmer_dnc.npy"
neg_1000 = "/content/drive/My Drive/fasta dataset/A.thaliana1000indep_neg/kmer_dnc/A.thaliana1000indep_neg_kmer_dnc.npy"

x_train_pos = np.load(pos_5289) 
x_train_neg = np.load(neg_5289) 
x_test_pos = np.load(pos_1000) 
x_test_neg = np.load(neg_1000) 

y_train_pos = np.tile(1, 5289) 
y_train_neg = np.tile(0, 5289) 
y_test_pos = np.tile(1, 1000) 
y_test_neg = np.tile(0, 1000)

# %%
print(x_test_neg.shape)
print(y_test_neg.shape)
print(x_train_neg.shape)
print(y_train_neg.shape)

print(x_test_pos.shape)
print(y_test_pos.shape)
print(x_train_pos.shape)
print(y_train_pos.shape)
# Out:
# (1000, 16)
# (1000,)
# (5289, 16)
# (5289,)
# (1000, 16)
# (1000,)
# (5289, 16)
# (5289,)

# %%
x_training = np.concatenate((x_train_pos, x_train_neg), axis = 0)
y_training = np.concatenate((y_train_pos, y_train_neg))

x_test = np.concatenate((x_test_pos, x_test_neg), axis = 0)
y_test = np.concatenate((y_test_pos, y_test_neg))

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (2000, 16)
# (2000,)

# %%
seed = 40
np.random.seed(seed)

kf = KFold(n_splits=5, random_state=seed, shuffle=True)

# %%
test_avg_list = []

for c in range(1,100,10):
  test_avg = 0

  print(f'for c = {c}:')

  clf = SVC(C=c,  random_state = seed)
  val_accuracy_list = []
  train_accuracy_list = []
  test_accuracy_list = []

  for train_index, val_index in kf.split(x_training):

    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    clf.fit(X_train, y_train)

    y_val_pred = clf.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = clf.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    

  #test_avg = test_avg/(len(test_accuracy_list))
  #test_avg_list.append(test_avg)

  y_test_pred = clf.predict(x_test)
  test_accuracy = accuracy_score(y_test, y_test_pred)
  #test_avg = test_avg + test_accuracy
  #test_accuracy_list.append(test_accuracy)

  for i in range(0, len(train_accuracy_list)):
    print("train_accuracy : ", train_accuracy_list[i], "\tVal accuracy : ", val_accuracy_list[i])
  print(f'test accuracy for that c is = {test_accuracy}')
  print()
# Out:
# for c = 1:
# train_accuracy :  0.9961002127156701 	Val accuracy :  0.9929111531190926
# train_accuracy :  0.9970456156936894 	Val accuracy :  0.9914933837429112
# train_accuracy :  0.9963365634601749 	Val accuracy :  0.9919659735349716
# train_accuracy :  0.9966914805624483 	Val accuracy :  0.9905437352245863
# train_accuracy :  0.9963369963369964 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.9085
#
# for c = 11:
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9938563327032136
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.994328922495274
# train_accuracy :  0.9997636492554951 	Val accuracy :  0.9957466918714556
# train_accuracy :  1.0 	Val accuracy :  0.9929078014184397
# train_accuracy :  0.999881838591516 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.9135
#
# for c = 21:
# train_accuracy :  1.0 	Val accuracy :  0.9924385633270322
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  1.0 	Val accuracy :  0.9938563327032136
# train_accuracy :  1.0 	Val accuracy :  0.9938534278959811
# train_accuracy :  1.0 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.912
#
# for c = 31:
# train_accuracy :  1.0 	Val accuracy :  0.9929111531190926
# train_accuracy :  1.0 	Val accuracy :  0.9924385633270322
# train_accuracy :  1.0 	Val accuracy :  0.994328922495274
# train_accuracy :  1.0 	Val accuracy :  0.9933806146572104
# train_accuracy :  1.0 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.9115
#
# for c = 41:
# train_accuracy :  1.0 	Val accuracy :  0.9929111531190926
# train_accuracy :  1.0 	Val accuracy :  0.9929111531190926
# train_accuracy :  1.0 	Val accuracy :  0.9938563327032136
# train_accuracy :  1.0 	Val accuracy :  0.9943262411347518
# train_accuracy :  1.0 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.912
#
# for c = 51:
# train_accuracy :  1.0 	Val accuracy :  0.9929111531190926
# train_accuracy :  1.0 	Val accuracy :  0.9929111531190926
# train_accuracy :  1.0 	Val accuracy :  0.9938563327032136
# train_accuracy :  1.0 	Val accuracy :  0.9943262411347518
# train_accuracy :  1.0 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.912
#
# for c = 61:
# train_accuracy :  1.0 	Val accuracy :  0.9929111531190926
# train_accuracy :  1.0 	Val accuracy :  0.9929111531190926
# train_accuracy :  1.0 	Val accuracy :  0.9938563327032136
# train_accuracy :  1.0 	Val accuracy :  0.9943262411347518
# train_accuracy :  1.0 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.912
#
# for c = 71:
# train_accuracy :  1.0 	Val accuracy :  0.9929111531190926
# train_accuracy :  1.0 	Val accuracy :  0.9929111531190926
# train_accuracy :  1.0 	Val accuracy :  0.9938563327032136
# train_accuracy :  1.0 	Val accuracy :  0.9943262411347518
# train_accuracy :  1.0 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.912
#
# for c = 81:
# train_accuracy :  1.0 	Val accuracy :  0.9929111531190926
# train_accuracy :  1.0 	Val accuracy :  0.9929111531190926
# train_accuracy :  1.0 	Val accuracy :  0.9938563327032136
# train_accuracy :  1.0 	Val accuracy :  0.9943262411347518
# train_accuracy :  1.0 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.912
#
# for c = 91:
# train_accuracy :  1.0 	Val accuracy :  0.9929111531190926
# train_accuracy :  1.0 	Val accuracy :  0.9929111531190926
# train_accuracy :  1.0 	Val accuracy :  0.9938563327032136
# train_accuracy :  1.0 	Val accuracy :  0.9943262411347518
# train_accuracy :  1.0 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.912

# %%
test_avg_list = []

for c in range(11,20,1):
  test_avg = 0

  print(f'for c = {c}:')

  clf = SVC(C=c,  random_state = seed)
  val_accuracy_list = []
  train_accuracy_list = []
  test_accuracy_list = []

  for train_index, val_index in kf.split(x_training):

    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    clf.fit(X_train, y_train)

    y_val_pred = clf.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = clf.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    
    #test_avg = test_avg + test_accuracy
    #test_accuracy_list.append(test_accuracy)

  #test_avg = test_avg/(len(test_accuracy_list))
  #test_avg_list.append(test_avg)
  y_test_pred = clf.predict(x_test)
  test_accuracy = accuracy_score(y_test, y_test_pred)

  for i in range(0, len(train_accuracy_list)):
    print("train_accuracy : ", train_accuracy_list[i], "\tVal accuracy : ", val_accuracy_list[i])
  print(f'test accuracy for that c is = {test_accuracy}')
  print()
# Out:
# for c = 11:
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9938563327032136
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.994328922495274
# train_accuracy :  0.9997636492554951 	Val accuracy :  0.9957466918714556
# train_accuracy :  1.0 	Val accuracy :  0.9929078014184397
# train_accuracy :  0.999881838591516 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.9135
#
# for c = 12:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9938563327032136
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.995274102079395
# train_accuracy :  1.0 	Val accuracy :  0.9929078014184397
# train_accuracy :  0.999881838591516 	Val accuracy :  0.9957446808510638
# test accuracy for that c is = 0.914
#
# for c = 13:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9938563327032136
# train_accuracy :  1.0 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9929078014184397
# train_accuracy :  1.0 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.913
#
# for c = 14:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9938563327032136
# train_accuracy :  1.0 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9929078014184397
# train_accuracy :  1.0 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.913
#
# for c = 15:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9938563327032136
# train_accuracy :  1.0 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9933806146572104
# train_accuracy :  1.0 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.913
#
# for c = 16:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  1.0 	Val accuracy :  0.9938563327032136
# train_accuracy :  1.0 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9938534278959811
# train_accuracy :  1.0 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.913
#
# for c = 17:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  1.0 	Val accuracy :  0.9938563327032136
# train_accuracy :  1.0 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9943262411347518
# train_accuracy :  1.0 	Val accuracy :  0.9952718676122931
# test accuracy for that c is = 0.912
#
# for c = 18:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  1.0 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9943262411347518
# train_accuracy :  1.0 	Val accuracy :  0.9952718676122931
# test accuracy for that c is = 0.9125
#
# for c = 19:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  1.0 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9943262411347518
# train_accuracy :  1.0 	Val accuracy :  0.9947990543735225
# test accuracy for that c is = 0.9125

# %%
test_avg_list = []
c = 12
for x in range(1,10,1):
  test_avg = 0
  c = c + .1
  print(f'for c = {c}:')

  clf = SVC(C=c,  random_state = seed)
  val_accuracy_list = []
  train_accuracy_list = []
  test_accuracy_list = []

  for train_index, val_index in kf.split(x_training):

    X_train, X_val = x_training[train_index], x_training[val_index]
    y_train, y_val = y_training[train_index], y_training[val_index]
    
    clf.fit(X_train, y_train)

    y_val_pred = clf.predict(X_val)
    val_accuracy = accuracy_score(y_val, y_val_pred)
    val_accuracy_list.append(val_accuracy)

    y_train_pred = clf.predict(X_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_list.append(train_accuracy)

    
    #test_avg = test_avg + test_accuracy
    #test_accuracy_list.append(test_accuracy)

  #test_avg = test_avg/(len(test_accuracy_list))
  #test_avg_list.append(test_avg)
  y_test_pred = clf.predict(x_test)
  test_accuracy = accuracy_score(y_test, y_test_pred)

  for i in range(0, len(train_accuracy_list)):
    print("train_accuracy : ", train_accuracy_list[i], "\tVal accuracy : ", val_accuracy_list[i])
  print(f'test accuracy for that c is = {test_accuracy}')
  print()
# Out:
# for c = 12.1:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9938563327032136
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9929078014184397
# train_accuracy :  0.999881838591516 	Val accuracy :  0.9957446808510638
# test accuracy for that c is = 0.9135
#
# for c = 12.2:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9938563327032136
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9929078014184397
# train_accuracy :  0.999881838591516 	Val accuracy :  0.9957446808510638
# test accuracy for that c is = 0.913
#
# for c = 12.299999999999999:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9938563327032136
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9929078014184397
# train_accuracy :  0.999881838591516 	Val accuracy :  0.9952718676122931
# test accuracy for that c is = 0.913
#
# for c = 12.399999999999999:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9938563327032136
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9929078014184397
# train_accuracy :  0.999881838591516 	Val accuracy :  0.9952718676122931
# test accuracy for that c is = 0.913
#
# for c = 12.499999999999998:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9938563327032136
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9929078014184397
# train_accuracy :  0.999881838591516 	Val accuracy :  0.9952718676122931
# test accuracy for that c is = 0.913
#
# for c = 12.599999999999998:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9938563327032136
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9929078014184397
# train_accuracy :  0.999881838591516 	Val accuracy :  0.9952718676122931
# test accuracy for that c is = 0.9125
#
# for c = 12.699999999999998:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9938563327032136
# train_accuracy :  1.0 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9929078014184397
# train_accuracy :  0.999881838591516 	Val accuracy :  0.9952718676122931
# test accuracy for that c is = 0.9135
#
# for c = 12.799999999999997:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9938563327032136
# train_accuracy :  1.0 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9929078014184397
# train_accuracy :  0.999881838591516 	Val accuracy :  0.9952718676122931
# test accuracy for that c is = 0.913
#
# for c = 12.899999999999997:
# train_accuracy :  1.0 	Val accuracy :  0.9933837429111532
# train_accuracy :  0.9998818246277476 	Val accuracy :  0.9938563327032136
# train_accuracy :  1.0 	Val accuracy :  0.9948015122873346
# train_accuracy :  1.0 	Val accuracy :  0.9929078014184397
# train_accuracy :  1.0 	Val accuracy :  0.9952718676122931
# test accuracy for that c is = 0.913
